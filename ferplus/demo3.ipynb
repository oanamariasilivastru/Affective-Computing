# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Flatten, Dense,
                                     Dropout, BatchNormalization)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import (ReduceLROnPlateau, EarlyStopping,
                                        ModelCheckpoint)
from sklearn.utils import shuffle
from sklearn.metrics import classification_report, confusion_matrix

# 1. Data Loading and Preprocessing
data = pd.read_csv('fer2013.csv')
pixels = data['pixels'].tolist()
emotions = data['emotion'].values

# Convert pixel strings to numpy arrays
X = np.array([np.fromstring(pixel_sequence, dtype='float32', sep=' ')
              for pixel_sequence in pixels])

# Normalize pixel values
X /= 255.0

# Reshape to (num_samples, 48, 48, 1)
X = X.reshape(-1, 48, 48, 1)

# Convert labels to categorical
y = to_categorical(emotions, num_classes=7)

# Shuffle data
X, y = shuffle(X, y, random_state=42)

# Split into training and testing sets
num_samples = X.shape[0]
num_train_samples = int(0.8 * num_samples)
X_train = X[:num_train_samples]
Y_train = y[:num_train_samples]
X_test = X[num_train_samples:]
Y_test = y[num_train_samples:]

# 2. Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)
datagen.fit(X_train)

# 3. Define the Simple CNN Model
def create_simple_cnn(input_shape=(48, 48, 1), num_classes=7):
    model = Sequential()
    model.add(Conv2D(32, (3,3), activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2,2)))
    
    model.add(Conv2D(64, (3,3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2,2)))
    
    model.add(Conv2D(128, (3,3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2,2)))
    
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    
    model.add(Dense(num_classes, activation='softmax'))
    
    # Compile the model
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

model = create_simple_cnn()

# 4. Configure Callbacks
callbacks = [
    ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=5,
        verbose=1,
        min_delta=1e-4
    ),
    EarlyStopping(
        monitor='val_accuracy',
        patience=15,
        verbose=1,
        restore_best_weights=True
    ),
    ModelCheckpoint(
        'best_simple_cnn_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

# 5. Train the Model (without class_weight)
batch_size = 64
epochs = 100

history = model.fit(
    datagen.flow(X_train, Y_train, batch_size=batch_size, shuffle=True),
    validation_data=(X_test, Y_test),
    epochs=epochs,
    callbacks=callbacks,
    verbose=2
)

# 6. Evaluate the Model
scores = model.evaluate(X_test, Y_test, verbose=0)
print(f'Test Accuracy: {scores[1]*100:.2f}%')

# 7. Generate Classification Report and Confusion Matrix
Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)
y_true = np.argmax(Y_test, axis=1)

print('Classification Report')
print(classification_report(y_true, y_pred, digits=4))

print('Confusion Matrix')
cm = confusion_matrix(y_true, y_pred)

# 8. Visualize the Confusion Matrix
# (Code for plotting the confusion matrix)

# 9. Plot Accuracy and Loss
# (Code for plotting the graphs)

# 10. Save the Model
model.save('emotion_detection_simple_cnn.keras')
# Out:
# Epoch 1/100
# c:\Users\Oana\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Oana\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1: val_accuracy improved from -inf to 0.30301, saving model to best_simple_cnn_model.keras
# 449/449 - 47s - 105ms/step - accuracy: 0.2138 - loss: 2.5804 - val_accuracy: 0.3030 - val_loss: 1.8372 - learning_rate: 1.0000e-04
# Epoch 2/100
#
# Epoch 2: val_accuracy improved from 0.30301 to 0.40513, saving model to best_simple_cnn_model.keras
# 449/449 - 47s - 105ms/step - accuracy: 0.2771 - loss: 2.1962 - val_accuracy: 0.4051 - val_loss: 1.6523 - learning_rate: 1.0000e-04
# Epoch 3/100
#
# Epoch 3: val_accuracy improved from 0.40513 to 0.40917, saving model to best_simple_cnn_model.keras
# 449/449 - 51s - 114ms/step - accuracy: 0.3101 - loss: 2.0213 - val_accuracy: 0.4092 - val_loss: 1.6046 - learning_rate: 1.0000e-04
# Epoch 4/100
#
# Epoch 4: val_accuracy improved from 0.40917 to 0.43982, saving model to best_simple_cnn_model.keras
# 449/449 - 50s - 112ms/step - accuracy: 0.3425 - loss: 1.8952 - val_accuracy: 0.4398 - val_loss: 1.4965 - learning_rate: 1.0000e-04
# Epoch 5/100
#
# Epoch 5: val_accuracy improved from 0.43982 to 0.46615, saving model to best_simple_cnn_model.keras
# 449/449 - 50s - 112ms/step - accuracy: 0.3634 - loss: 1.7916 - val_accuracy: 0.4661 - val_loss: 1.4187 - learning_rate: 1.0000e-04
# Epoch 6/100
#
# Epoch 6: val_accuracy did not improve from 0.46615
# 449/449 - 53s - 117ms/step - accuracy: 0.3870 - loss: 1.7086 - val_accuracy: 0.4558 - val_loss: 1.4650 - learning_rate: 1.0000e-04
# Epoch 7/100
#
# Epoch 7: val_accuracy improved from 0.46615 to 0.47952, saving model to best_simple_cnn_model.keras
# 449/449 - 52s - 115ms/step - accuracy: 0.3989 - loss: 1.6455 - val_accuracy: 0.4795 - val_loss: 1.3725 - learning_rate: 1.0000e-04
# Epoch 8/100
#
# Epoch 8: val_accuracy improved from 0.47952 to 0.49944, saving model to best_simple_cnn_model.keras
# 449/449 - 50s - 112ms/step - accuracy: 0.4121 - loss: 1.5807 - val_accuracy: 0.4994 - val_loss: 1.3315 - learning_rate: 1.0000e-04
# Epoch 9/100
#
# Epoch 9: val_accuracy improved from 0.49944 to 0.50975, saving model to best_simple_cnn_model.keras
# 449/449 - 53s - 118ms/step - accuracy: 0.4284 - loss: 1.5380 - val_accuracy: 0.5098 - val_loss: 1.3143 - learning_rate: 1.0000e-04
# Epoch 10/100
#
# Epoch 10: val_accuracy did not improve from 0.50975
# 449/449 - 52s - 115ms/step - accuracy: 0.4394 - loss: 1.4963 - val_accuracy: 0.5059 - val_loss: 1.2983 - learning_rate: 1.0000e-04
# Epoch 11/100
#
# Epoch 11: val_accuracy improved from 0.50975 to 0.51505, saving model to best_simple_cnn_model.keras
# 449/449 - 45s - 100ms/step - accuracy: 0.4538 - loss: 1.4550 - val_accuracy: 0.5150 - val_loss: 1.3077 - learning_rate: 1.0000e-04
# Epoch 12/100
#
# Epoch 12: val_accuracy did not improve from 0.51505
# 449/449 - 45s - 99ms/step - accuracy: 0.4599 - loss: 1.4255 - val_accuracy: 0.5096 - val_loss: 1.3141 - learning_rate: 1.0000e-04
# Epoch 13/100
#
# Epoch 13: val_accuracy did not improve from 0.51505
# 449/449 - 45s - 100ms/step - accuracy: 0.4673 - loss: 1.4019 - val_accuracy: 0.5091 - val_loss: 1.3149 - learning_rate: 1.0000e-04
# Epoch 14/100
#
# Epoch 14: val_accuracy improved from 0.51505 to 0.52522, saving model to best_simple_cnn_model.keras
# 449/449 - 49s - 109ms/step - accuracy: 0.4807 - loss: 1.3751 - val_accuracy: 0.5252 - val_loss: 1.2612 - learning_rate: 1.0000e-04
# Epoch 15/100
#
# Epoch 15: val_accuracy improved from 0.52522 to 0.53998, saving model to best_simple_cnn_model.keras
# 449/449 - 51s - 114ms/step - accuracy: 0.4851 - loss: 1.3522 - val_accuracy: 0.5400 - val_loss: 1.2328 - learning_rate: 1.0000e-04
# Epoch 16/100
#
# Epoch 16: val_accuracy did not improve from 0.53998
# 449/449 - 49s - 109ms/step - accuracy: 0.4925 - loss: 1.3314 - val_accuracy: 0.5385 - val_loss: 1.2251 - learning_rate: 1.0000e-04
# Epoch 17/100
#
# Epoch 17: val_accuracy did not improve from 0.53998
# 449/449 - 49s - 109ms/step - accuracy: 0.5001 - loss: 1.3146 - val_accuracy: 0.5334 - val_loss: 1.2317 - learning_rate: 1.0000e-04
# Epoch 18/100
#
# Epoch 18: val_accuracy improved from 0.53998 to 0.54570, saving model to best_simple_cnn_model.keras
# 449/449 - 46s - 102ms/step - accuracy: 0.5060 - loss: 1.3015 - val_accuracy: 0.5457 - val_loss: 1.2178 - learning_rate: 1.0000e-04
# Epoch 19/100
#
# Epoch 19: val_accuracy improved from 0.54570 to 0.54987, saving model to best_simple_cnn_model.keras
# 449/449 - 44s - 98ms/step - accuracy: 0.5117 - loss: 1.2863 - val_accuracy: 0.5499 - val_loss: 1.1924 - learning_rate: 1.0000e-04
# Epoch 20/100
#
# Epoch 20: val_accuracy did not improve from 0.54987
# 449/449 - 46s - 103ms/step - accuracy: 0.5219 - loss: 1.2681 - val_accuracy: 0.4907 - val_loss: 1.3421 - learning_rate: 1.0000e-04
# Epoch 21/100
#
# Epoch 21: val_accuracy improved from 0.54987 to 0.55879, saving model to best_simple_cnn_model.keras
# 449/449 - 47s - 104ms/step - accuracy: 0.5190 - loss: 1.2632 - val_accuracy: 0.5588 - val_loss: 1.1749 - learning_rate: 1.0000e-04
# Epoch 22/100
#
# Epoch 22: val_accuracy did not improve from 0.55879
# 449/449 - 49s - 109ms/step - accuracy: 0.5274 - loss: 1.2498 - val_accuracy: 0.5535 - val_loss: 1.1836 - learning_rate: 1.0000e-04
# Epoch 23/100
#
# Epoch 23: val_accuracy did not improve from 0.55879
# 449/449 - 49s - 110ms/step - accuracy: 0.5308 - loss: 1.2386 - val_accuracy: 0.5543 - val_loss: 1.1853 - learning_rate: 1.0000e-04
# Epoch 24/100
#
# Epoch 24: val_accuracy improved from 0.55879 to 0.56464, saving model to best_simple_cnn_model.keras
# 449/449 - 50s - 112ms/step - accuracy: 0.5366 - loss: 1.2269 - val_accuracy: 0.5646 - val_loss: 1.1501 - learning_rate: 1.0000e-04
# Epoch 25/100
#
# Epoch 25: val_accuracy did not improve from 0.56464
# 449/449 - 53s - 118ms/step - accuracy: 0.5393 - loss: 1.2152 - val_accuracy: 0.5446 - val_loss: 1.2070 - learning_rate: 1.0000e-04
# Epoch 26/100
#
# Epoch 26: val_accuracy did not improve from 0.56464
# 449/449 - 50s - 111ms/step - accuracy: 0.5399 - loss: 1.2116 - val_accuracy: 0.5617 - val_loss: 1.1556 - learning_rate: 1.0000e-04
# Epoch 27/100
#
# Epoch 27: val_accuracy improved from 0.56464 to 0.57008, saving model to best_simple_cnn_model.keras
# 449/449 - 52s - 117ms/step - accuracy: 0.5444 - loss: 1.2053 - val_accuracy: 0.5701 - val_loss: 1.1297 - learning_rate: 1.0000e-04
# Epoch 28/100
#
# Epoch 28: val_accuracy did not improve from 0.57008
# 449/449 - 49s - 108ms/step - accuracy: 0.5457 - loss: 1.2015 - val_accuracy: 0.5678 - val_loss: 1.1519 - learning_rate: 1.0000e-04
# Epoch 29/100
#
# Epoch 29: val_accuracy improved from 0.57008 to 0.57885, saving model to best_simple_cnn_model.keras
# 449/449 - 45s - 99ms/step - accuracy: 0.5479 - loss: 1.1867 - val_accuracy: 0.5789 - val_loss: 1.1274 - learning_rate: 1.0000e-04
# Epoch 30/100
#
# Epoch 30: val_accuracy did not improve from 0.57885
# 449/449 - 45s - 100ms/step - accuracy: 0.5513 - loss: 1.1830 - val_accuracy: 0.5752 - val_loss: 1.1133 - learning_rate: 1.0000e-04
# Epoch 31/100
#
# Epoch 31: val_accuracy did not improve from 0.57885
# 449/449 - 49s - 110ms/step - accuracy: 0.5552 - loss: 1.1731 - val_accuracy: 0.5712 - val_loss: 1.1204 - learning_rate: 1.0000e-04
# Epoch 32/100
#
# Epoch 32: val_accuracy improved from 0.57885 to 0.58624, saving model to best_simple_cnn_model.keras
# 449/449 - 45s - 101ms/step - accuracy: 0.5609 - loss: 1.1623 - val_accuracy: 0.5862 - val_loss: 1.1088 - learning_rate: 1.0000e-04
# Epoch 33/100
#
# Epoch 33: val_accuracy did not improve from 0.58624
# 449/449 - 44s - 98ms/step - accuracy: 0.5615 - loss: 1.1627 - val_accuracy: 0.5712 - val_loss: 1.1440 - learning_rate: 1.0000e-04
# Epoch 34/100
#
# Epoch 34: val_accuracy did not improve from 0.58624
# 449/449 - 46s - 102ms/step - accuracy: 0.5632 - loss: 1.1567 - val_accuracy: 0.5862 - val_loss: 1.1004 - learning_rate: 1.0000e-04
# Epoch 35/100
#
# Epoch 35: val_accuracy did not improve from 0.58624
# 449/449 - 46s - 102ms/step - accuracy: 0.5642 - loss: 1.1482 - val_accuracy: 0.5716 - val_loss: 1.1424 - learning_rate: 1.0000e-04
# Epoch 36/100
#
# Epoch 36: val_accuracy did not improve from 0.58624
# 449/449 - 45s - 99ms/step - accuracy: 0.5665 - loss: 1.1408 - val_accuracy: 0.5826 - val_loss: 1.0962 - learning_rate: 1.0000e-04
# Epoch 37/100
#
# Epoch 37: val_accuracy improved from 0.58624 to 0.58721, saving model to best_simple_cnn_model.keras
# 449/449 - 45s - 99ms/step - accuracy: 0.5679 - loss: 1.1407 - val_accuracy: 0.5872 - val_loss: 1.0854 - learning_rate: 1.0000e-04
# Epoch 38/100
#
# Epoch 38: val_accuracy improved from 0.58721 to 0.58735, saving model to best_simple_cnn_model.keras
# 449/449 - 45s - 101ms/step - accuracy: 0.5732 - loss: 1.1282 - val_accuracy: 0.5874 - val_loss: 1.0948 - learning_rate: 1.0000e-04
# Epoch 39/100
#
# Epoch 39: val_accuracy did not improve from 0.58735
# 449/449 - 45s - 101ms/step - accuracy: 0.5711 - loss: 1.1311 - val_accuracy: 0.5826 - val_loss: 1.0998 - learning_rate: 1.0000e-04
# Epoch 40/100
#
# Epoch 40: val_accuracy did not improve from 0.58735
# 449/449 - 46s - 103ms/step - accuracy: 0.5728 - loss: 1.1249 - val_accuracy: 0.5857 - val_loss: 1.0993 - learning_rate: 1.0000e-04
# Epoch 41/100
#
# Epoch 41: val_accuracy improved from 0.58735 to 0.59641, saving model to best_simple_cnn_model.keras
# 449/449 - 47s - 105ms/step - accuracy: 0.5742 - loss: 1.1231 - val_accuracy: 0.5964 - val_loss: 1.0678 - learning_rate: 1.0000e-04
# Epoch 42/100
#
# Epoch 42: val_accuracy did not improve from 0.59641
# 449/449 - 45s - 99ms/step - accuracy: 0.5785 - loss: 1.1106 - val_accuracy: 0.5832 - val_loss: 1.0993 - learning_rate: 1.0000e-04
# Epoch 43/100
#
# Epoch 43: val_accuracy did not improve from 0.59641
# 449/449 - 44s - 98ms/step - accuracy: 0.5820 - loss: 1.1105 - val_accuracy: 0.5957 - val_loss: 1.0688 - learning_rate: 1.0000e-04
# Epoch 44/100
#
# Epoch 44: val_accuracy did not improve from 0.59641
# 449/449 - 44s - 98ms/step - accuracy: 0.5799 - loss: 1.1035 - val_accuracy: 0.5950 - val_loss: 1.0783 - learning_rate: 1.0000e-04
# Epoch 45/100
#
# Epoch 45: val_accuracy improved from 0.59641 to 0.60198, saving model to best_simple_cnn_model.keras
# 449/449 - 45s - 99ms/step - accuracy: 0.5846 - loss: 1.0964 - val_accuracy: 0.6020 - val_loss: 1.0729 - learning_rate: 1.0000e-04
# Epoch 46/100
#
# Epoch 46: val_accuracy did not improve from 0.60198
# 449/449 - 45s - 99ms/step - accuracy: 0.5858 - loss: 1.0977 - val_accuracy: 0.5950 - val_loss: 1.0819 - learning_rate: 1.0000e-04
# Epoch 47/100
#
# Epoch 47: val_accuracy did not improve from 0.60198
# 449/449 - 45s - 101ms/step - accuracy: 0.5850 - loss: 1.0992 - val_accuracy: 0.5991 - val_loss: 1.0608 - learning_rate: 1.0000e-04
# Epoch 48/100
#
# Epoch 48: val_accuracy did not improve from 0.60198
# 449/449 - 44s - 98ms/step - accuracy: 0.5887 - loss: 1.0877 - val_accuracy: 0.5979 - val_loss: 1.0667 - learning_rate: 1.0000e-04
# Epoch 49/100
#
# Epoch 49: val_accuracy did not improve from 0.60198
# 449/449 - 44s - 98ms/step - accuracy: 0.5936 - loss: 1.0852 - val_accuracy: 0.5777 - val_loss: 1.1201 - learning_rate: 1.0000e-04
# Epoch 50/100
#
# Epoch 50: val_accuracy improved from 0.60198 to 0.60240, saving model to best_simple_cnn_model.keras
# 449/449 - 44s - 98ms/step - accuracy: 0.5907 - loss: 1.0868 - val_accuracy: 0.6024 - val_loss: 1.0510 - learning_rate: 1.0000e-04
# Epoch 51/100
#
# Epoch 51: val_accuracy improved from 0.60240 to 0.60644, saving model to best_simple_cnn_model.keras
# 449/449 - 44s - 98ms/step - accuracy: 0.5939 - loss: 1.0736 - val_accuracy: 0.6064 - val_loss: 1.0414 - learning_rate: 1.0000e-04
# Epoch 52/100
#
# Epoch 52: val_accuracy did not improve from 0.60644
# 449/449 - 44s - 98ms/step - accuracy: 0.5955 - loss: 1.0734 - val_accuracy: 0.5847 - val_loss: 1.1104 - learning_rate: 1.0000e-04
# Epoch 53/100
#
# Epoch 53: val_accuracy did not improve from 0.60644
# 449/449 - 45s - 99ms/step - accuracy: 0.5978 - loss: 1.0700 - val_accuracy: 0.6042 - val_loss: 1.0469 - learning_rate: 1.0000e-04
# Epoch 54/100
#
# Epoch 54: val_accuracy did not improve from 0.60644
# 449/449 - 44s - 99ms/step - accuracy: 0.5953 - loss: 1.0705 - val_accuracy: 0.6048 - val_loss: 1.0539 - learning_rate: 1.0000e-04
# Epoch 55/100
#
# Epoch 55: val_accuracy improved from 0.60644 to 0.60894, saving model to best_simple_cnn_model.keras
# 449/449 - 44s - 98ms/step - accuracy: 0.5971 - loss: 1.0667 - val_accuracy: 0.6089 - val_loss: 1.0364 - learning_rate: 1.0000e-04
# Epoch 56/100
#
# Epoch 56: val_accuracy did not improve from 0.60894
# 449/449 - 44s - 98ms/step - accuracy: 0.5996 - loss: 1.0616 - val_accuracy: 0.6006 - val_loss: 1.0611 - learning_rate: 1.0000e-04
# Epoch 57/100
#
# Epoch 57: val_accuracy improved from 0.60894 to 0.61591, saving model to best_simple_cnn_model.keras
# 449/449 - 44s - 98ms/step - accuracy: 0.5989 - loss: 1.0564 - val_accuracy: 0.6159 - val_loss: 1.0331 - learning_rate: 1.0000e-04
# Epoch 58/100
#
# Epoch 58: val_accuracy did not improve from 0.61591
# 449/449 - 44s - 98ms/step - accuracy: 0.6077 - loss: 1.0525 - val_accuracy: 0.6069 - val_loss: 1.0468 - learning_rate: 1.0000e-04
# Epoch 59/100
#
# Epoch 59: val_accuracy did not improve from 0.61591
# 449/449 - 44s - 98ms/step - accuracy: 0.6063 - loss: 1.0458 - val_accuracy: 0.6017 - val_loss: 1.0542 - learning_rate: 1.0000e-04
# Epoch 60/100
#
# Epoch 60: val_accuracy did not improve from 0.61591
# 449/449 - 44s - 98ms/step - accuracy: 0.6043 - loss: 1.0475 - val_accuracy: 0.6137 - val_loss: 1.0314 - learning_rate: 1.0000e-04
# Epoch 61/100
#
# Epoch 61: val_accuracy did not improve from 0.61591
# 449/449 - 44s - 98ms/step - accuracy: 0.6103 - loss: 1.0436 - val_accuracy: 0.6076 - val_loss: 1.0442 - learning_rate: 1.0000e-04
# Epoch 62/100
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 62: val_accuracy did not improve from 0.61591
# 449/449 - 44s - 98ms/step - accuracy: 0.6079 - loss: 1.0445 - val_accuracy: 0.6152 - val_loss: 1.0352 - learning_rate: 1.0000e-04
# Epoch 63/100
#
# Epoch 63: val_accuracy did not improve from 0.61591
# 449/449 - 45s - 100ms/step - accuracy: 0.6140 - loss: 1.0279 - val_accuracy: 0.6123 - val_loss: 1.0270 - learning_rate: 5.0000e-05
# Epoch 64/100
#
# Epoch 64: val_accuracy improved from 0.61591 to 0.61884, saving model to best_simple_cnn_model.keras
# 449/449 - 45s - 100ms/step - accuracy: 0.6165 - loss: 1.0195 - val_accuracy: 0.6188 - val_loss: 1.0143 - learning_rate: 5.0000e-05
# Epoch 65/100
#
# Epoch 65: val_accuracy did not improve from 0.61884
# 449/449 - 44s - 99ms/step - accuracy: 0.6129 - loss: 1.0274 - val_accuracy: 0.6184 - val_loss: 1.0177 - learning_rate: 5.0000e-05
# Epoch 66/100
#
# Epoch 66: val_accuracy did not improve from 0.61884
# 449/449 - 44s - 99ms/step - accuracy: 0.6144 - loss: 1.0185 - val_accuracy: 0.6064 - val_loss: 1.0489 - learning_rate: 5.0000e-05
# Epoch 67/100
#
# Epoch 67: val_accuracy did not improve from 0.61884
# 449/449 - 45s - 99ms/step - accuracy: 0.6160 - loss: 1.0146 - val_accuracy: 0.6181 - val_loss: 1.0247 - learning_rate: 5.0000e-05
# Epoch 68/100
#
# Epoch 68: val_accuracy improved from 0.61884 to 0.62009, saving model to best_simple_cnn_model.keras
# 449/449 - 45s - 99ms/step - accuracy: 0.6197 - loss: 1.0086 - val_accuracy: 0.6201 - val_loss: 1.0238 - learning_rate: 5.0000e-05
# Epoch 69/100
#
# Epoch 69: val_accuracy improved from 0.62009 to 0.62260, saving model to best_simple_cnn_model.keras
# 449/449 - 45s - 99ms/step - accuracy: 0.6215 - loss: 1.0093 - val_accuracy: 0.6226 - val_loss: 1.0176 - learning_rate: 5.0000e-05
# Epoch 70/100
#
# Epoch 70: val_accuracy did not improve from 0.62260
# 449/449 - 44s - 99ms/step - accuracy: 0.6197 - loss: 1.0116 - val_accuracy: 0.6191 - val_loss: 1.0254 - learning_rate: 5.0000e-05
# Epoch 71/100
#
# Epoch 71: val_accuracy did not improve from 0.62260
# 449/449 - 45s - 100ms/step - accuracy: 0.6223 - loss: 1.0081 - val_accuracy: 0.6225 - val_loss: 1.0100 - learning_rate: 5.0000e-05
# Epoch 72/100
#
# Epoch 72: val_accuracy did not improve from 0.62260
# 449/449 - 45s - 99ms/step - accuracy: 0.6185 - loss: 1.0136 - val_accuracy: 0.6225 - val_loss: 1.0092 - learning_rate: 5.0000e-05
# Epoch 73/100
#
# Epoch 73: val_accuracy did not improve from 0.62260
# 449/449 - 45s - 100ms/step - accuracy: 0.6237 - loss: 1.0036 - val_accuracy: 0.5922 - val_loss: 1.0882 - learning_rate: 5.0000e-05
# Epoch 74/100
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 74: val_accuracy did not improve from 0.62260
# 449/449 - 46s - 102ms/step - accuracy: 0.6240 - loss: 1.0044 - val_accuracy: 0.6220 - val_loss: 1.0175 - learning_rate: 5.0000e-05
# Epoch 75/100
#
# Epoch 75: val_accuracy improved from 0.62260 to 0.62928, saving model to best_simple_cnn_model.keras
# 449/449 - 51s - 114ms/step - accuracy: 0.6236 - loss: 0.9975 - val_accuracy: 0.6293 - val_loss: 1.0033 - learning_rate: 2.5000e-05
# Epoch 76/100
#
# Epoch 76: val_accuracy did not improve from 0.62928
# 449/449 - 48s - 106ms/step - accuracy: 0.6291 - loss: 0.9956 - val_accuracy: 0.6241 - val_loss: 1.0096 - learning_rate: 2.5000e-05
# Epoch 77/100
#
# Epoch 77: val_accuracy did not improve from 0.62928
# 449/449 - 47s - 106ms/step - accuracy: 0.6243 - loss: 0.9943 - val_accuracy: 0.6236 - val_loss: 1.0083 - learning_rate: 2.5000e-05
# Epoch 78/100
#
# Epoch 78: val_accuracy did not improve from 0.62928
# 449/449 - 47s - 106ms/step - accuracy: 0.6262 - loss: 0.9950 - val_accuracy: 0.6251 - val_loss: 1.0137 - learning_rate: 2.5000e-05
# Epoch 79/100
#
# Epoch 79: val_accuracy did not improve from 0.62928
# 449/449 - 48s - 106ms/step - accuracy: 0.6238 - loss: 0.9989 - val_accuracy: 0.6250 - val_loss: 1.0123 - learning_rate: 2.5000e-05
# Epoch 80/100
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 80: val_accuracy did not improve from 0.62928
# 449/449 - 47s - 105ms/step - accuracy: 0.6260 - loss: 0.9912 - val_accuracy: 0.6257 - val_loss: 1.0142 - learning_rate: 2.5000e-05
# Epoch 81/100
#
# Epoch 81: val_accuracy did not improve from 0.62928
# 449/449 - 50s - 112ms/step - accuracy: 0.6320 - loss: 0.9864 - val_accuracy: 0.6293 - val_loss: 1.0003 - learning_rate: 1.2500e-05
# Epoch 82/100
#
# Epoch 82: val_accuracy improved from 0.62928 to 0.62984, saving model to best_simple_cnn_model.keras
# 449/449 - 51s - 113ms/step - accuracy: 0.6279 - loss: 0.9854 - val_accuracy: 0.6298 - val_loss: 1.0004 - learning_rate: 1.2500e-05
# Epoch 83/100
#
# Epoch 83: val_accuracy did not improve from 0.62984
# 449/449 - 50s - 112ms/step - accuracy: 0.6319 - loss: 0.9811 - val_accuracy: 0.6278 - val_loss: 1.0066 - learning_rate: 1.2500e-05
# Epoch 84/100
#
# Epoch 84: val_accuracy did not improve from 0.62984
# 449/449 - 49s - 109ms/step - accuracy: 0.6282 - loss: 0.9853 - val_accuracy: 0.6272 - val_loss: 1.0021 - learning_rate: 1.2500e-05
# Epoch 85/100
#
# Epoch 85: val_accuracy did not improve from 0.62984
# 449/449 - 49s - 109ms/step - accuracy: 0.6317 - loss: 0.9848 - val_accuracy: 0.6290 - val_loss: 0.9983 - learning_rate: 1.2500e-05
# Epoch 86/100
#
# Epoch 86: val_accuracy did not improve from 0.62984
# 449/449 - 49s - 110ms/step - accuracy: 0.6307 - loss: 0.9808 - val_accuracy: 0.6275 - val_loss: 1.0007 - learning_rate: 1.2500e-05
# Epoch 87/100
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 87: val_accuracy did not improve from 0.62984
# 449/449 - 50s - 111ms/step - accuracy: 0.6326 - loss: 0.9867 - val_accuracy: 0.6269 - val_loss: 0.9999 - learning_rate: 1.2500e-05
# Epoch 88/100
#
# Epoch 88: val_accuracy did not improve from 0.62984
# 449/449 - 46s - 103ms/step - accuracy: 0.6330 - loss: 0.9774 - val_accuracy: 0.6275 - val_loss: 1.0020 - learning_rate: 6.2500e-06
# Epoch 89/100
#
# Epoch 89: val_accuracy did not improve from 0.62984
# 449/449 - 44s - 99ms/step - accuracy: 0.6328 - loss: 0.9801 - val_accuracy: 0.6297 - val_loss: 0.9999 - learning_rate: 6.2500e-06
# Epoch 90/100
#
# Epoch 90: val_accuracy did not improve from 0.62984
# 449/449 - 49s - 108ms/step - accuracy: 0.6337 - loss: 0.9775 - val_accuracy: 0.6275 - val_loss: 0.9999 - learning_rate: 6.2500e-06
# Epoch 91/100
#
# Epoch 91: val_accuracy did not improve from 0.62984
# 449/449 - 45s - 100ms/step - accuracy: 0.6294 - loss: 0.9811 - val_accuracy: 0.6289 - val_loss: 0.9984 - learning_rate: 6.2500e-06
# Epoch 92/100
#
# Epoch 92: val_accuracy improved from 0.62984 to 0.63026, saving model to best_simple_cnn_model.keras
# 449/449 - 45s - 99ms/step - accuracy: 0.6322 - loss: 0.9843 - val_accuracy: 0.6303 - val_loss: 0.9971 - learning_rate: 6.2500e-06
# Epoch 93/100
#
# Epoch 93: val_accuracy did not improve from 0.63026
# 449/449 - 45s - 101ms/step - accuracy: 0.6300 - loss: 0.9804 - val_accuracy: 0.6282 - val_loss: 0.9996 - learning_rate: 6.2500e-06
# Epoch 94/100
#
# Epoch 94: val_accuracy did not improve from 0.63026
# 449/449 - 47s - 105ms/step - accuracy: 0.6304 - loss: 0.9789 - val_accuracy: 0.6286 - val_loss: 0.9981 - learning_rate: 6.2500e-06
# Epoch 95/100
#
# Epoch 95: val_accuracy did not improve from 0.63026
# 449/449 - 50s - 110ms/step - accuracy: 0.6353 - loss: 0.9717 - val_accuracy: 0.6303 - val_loss: 0.9970 - learning_rate: 6.2500e-06
# Epoch 96/100
#
# Epoch 96: val_accuracy did not improve from 0.63026
# 449/449 - 49s - 109ms/step - accuracy: 0.6340 - loss: 0.9730 - val_accuracy: 0.6289 - val_loss: 0.9981 - learning_rate: 6.2500e-06
# Epoch 97/100
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 97: val_accuracy did not improve from 0.63026
# 449/449 - 49s - 109ms/step - accuracy: 0.6336 - loss: 0.9770 - val_accuracy: 0.6294 - val_loss: 0.9976 - learning_rate: 6.2500e-06
# Epoch 98/100
#
# Epoch 98: val_accuracy did not improve from 0.63026
# 449/449 - 49s - 108ms/step - accuracy: 0.6343 - loss: 0.9757 - val_accuracy: 0.6303 - val_loss: 0.9976 - learning_rate: 3.1250e-06
# Epoch 99/100
#
# Epoch 99: val_accuracy improved from 0.63026 to 0.63082, saving model to best_simple_cnn_model.keras
# 449/449 - 47s - 105ms/step - accuracy: 0.6313 - loss: 0.9761 - val_accuracy: 0.6308 - val_loss: 0.9967 - learning_rate: 3.1250e-06
# Epoch 100/100
#
# Epoch 100: val_accuracy did not improve from 0.63082
# 449/449 - 46s - 103ms/step - accuracy: 0.6296 - loss: 0.9778 - val_accuracy: 0.6296 - val_loss: 0.9963 - learning_rate: 3.1250e-06
# Restoring model weights from the end of the best epoch: 99.
# Test Accuracy: 63.08%
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0     0.5373    0.5799    0.5578       957
#            1     0.6739    0.2696    0.3851       115
#            2     0.4895    0.3614    0.4158      1032
#            3     0.8321    0.8473    0.8396      1807
#            4     0.5484    0.4930    0.5192      1219
#            5     0.7531    0.7240    0.7383       826
#            6     0.5221    0.6866    0.5931      1222
#
#     accuracy                         0.6308      7178
#    macro avg     0.6223    0.5660    0.5784      7178
# weighted avg     0.6309    0.6308    0.6258      7178
#
# Confusion Matrix
